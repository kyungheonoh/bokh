# %%
import requests
from bs4 import BeautifulSoup

# 웹 페이지 요청
url = 'https://www.bok.or.kr/portal/bbs/P0000559/list.do?menuNo=200690'
response = requests.get(url, verify=True)

# HTML 파싱
soup = BeautifulSoup(response.text, 'html.parser')

# 필요한 데이터 추출 (예시: 제목과 날짜)
press_releases = []
for item in soup.select('.list a.title'):
    title = item.text.strip()
    date = item.find_next('span', {'class': 'date'}).text.strip()
    press_releases.append({
        'title': title,
        'date': date
    })

# 결과 출력
print(press_releases)
# Out:
# []

# %%
print(response.status_code)
# Out:
# 200

# %%
print(soup.prettify()[:500])
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    | 보도자료(목록) | 커뮤니케이션 |  한국은행 홈페이지
#   </title>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible">
#    <meta content="커뮤니케이션,한국은행,보도자료" name="kwrd">
#     <meta content="한국은행과 관련된 보도자료 제공 게시판" name="dc"/>
#     <meta content="보도자료" property="title"/>
#     <meta content="한국은행" property="main"/>
#     <meta content="" property="creator"/>
#     <meta conten

# %%
for link in soup.find_all('a'):
    print(link)
# Out:
# <a href="#content">본문내용 바로가기</a>
# <a href="#gnb">주메뉴 바로가기</a>
# <a class="ico1" href="https://ecos.bok.or.kr" target="_blank" title="새창열림"><strong><span class="hidden-sm">경제통계시스템(</span>ECOS<span class="hidden-sm">)</span></strong><i class="fa fa-angle-right ml10"></i></a>
# <a class="ico1" href="https://snapshot.bok.or.kr" target="_blank" title="새창열림"><strong>금융·경제 스냅샷</strong><i class="fa fa-angle-right ml10"></i></a>
# <a class="ico2" href="https://dl.bok.or.kr" target="_blank" title="새창열림"><strong>전자도서관</strong><i class="fa fa-angle-right ml10"></i></a>
# <a class="ico3" href="https://apply.bok.or.kr" target="_blank" title="새창열림"><strong>채용</strong><i class="fa fa-angle-right ml10"></i></a>
# <a class="ico1" href="https://bok.or.kr/history70" target="_blank" title="새창열림"><strong>한국은행 70주년</strong><i class="fa fa-angle-right ml10"></i></a>
# <a class="bar glogin" href="/portal/mber/bokMber/forSelfCrtfcSns.do?menuNo=200249">로그인</a>
# <a class="snsOpener" href="javascript:void(0);">
# <span class="hidden-lg hidden-md"><i aria-hidden="true" class="fa fa-share-alt vm"></i><strong class="hidden">한국은행 SNS</strong> <i aria-hidden="true" class="ti-angle-down vm"></i></span>
# <span class="hidden-sm"><strong>한국은행 SNS</strong> <i aria-hidden="true" class="fa fa-sort-desc vm"></i></span>
# </a>
# <a href="https://www.youtube.com/thebankofkoreakr" target="_blank" title="새창열림"><i class="icon icon-sns3"></i><span class="hidden">한국은행 Youtube 바로가기 (https://www.youtube.com/thebankofkoreakr)</span></a>
# <a href="https://www.facebook.com/bankofkoreahub" target="_blank" title="새창열림"><i class="icon icon-sns1"></i><span class="hidden">한국은행 Facebook 바로가기 (https://www.facebook.com/bankofkoreahub)</span></a>
# <a href="https://www.twitter.com/bok_hub" target="_blank" title="새창열림"><i class="icon icon-sns2"></i><span class="hidden">한국은행 Twitter 바로가기 (https://www.twitter.com/bok_hub)</span></a>
# <a href="https://story.kakao.com/#ch/bankofkorea" target="_blank" title="새창열림"><i class="icon icon-sns5"></i><span class="hidden">한국은행 카카오스토리  바로가기 (https://story.kakao.com/#ch/bankofkorea)</span></a>
# <a href="https://www.instagram.com/thebankofkorea/" target="_blank" title="새창열림"><i class="icon icon-sns4"></i><span class="hidden">한국은행 인스타그램  바로가기 (https://www.instagram.com/thebankofkorea)</span></a>
# <a class="language" href="/eng/main/main.do" title="영문홈페이지 바로가기">English</a>
# <a href="/imer/main/main.do"><span class="fa fa-mortar-board"></span> <span class="hidden-sm">경제연구원</span></a>
# <a href="/museum/main/main.do"><span class="fa fa-institution"></span> <span class="hidden-sm">화폐박물관</span></a>
# <a href="/portal/submain/submain/rgHqt.do?menuNo=200219"><span class="fa fa-building"></span> <span class="hidden-sm">지역본부</span></a>
# <a href="/portal/singl/coxhResve/listCldr.do?menuNo=201082"><span class="fa fa-coxh" style="padding-left:10px;"></span></a>
# <a href="javascript:void(0);"><i aria-hidden="true" class="fa fa-reorder"></i><span class="hidden">전체메뉴 열기</span></a>
# <a href="/portal/main/main.do"><span class="hidden">한국은행(The bank of Korea)</span></a>
# <a href="javascript:void(0);"><span aria-hidden="true" class="ti-search"></span><span class="hidden">검색창 열고 닫기</span></a>
# <a class="btnClose" href="javascript:void(0);" id="topSrchClose">자동완성 닫기</a>
# <a class="mainSchClose" href="javascript:void(0);"><span aria-hidden="true" class="ti-close"></span><span class="hidden">Close Search Layer</span></a>
# <a href="/portal/main/main.do"><span class="hidden">한국은행</span></a>
# <a href="javascript:void(0)"><i class="ti-close"></i><span class="hidden">메뉴닫기</span></a>
# <a data-href="/portal/submain/submain/bokIntrcn.do?viewType=SUBMAIN&amp;menuNo=200176" href="/portal/submain/submain/bokIntrcn.do?viewType=SUBMAIN&amp;menuNo=200176">한국은행</a>
# <a href="/portal/main/contents.do?menuNo=200181">한국은행 안내</a>
# <a href="/portal/main/contents.do?menuNo=200181">설립목적</a>
# <a href="/portal/main/contents.do?menuNo=200781">설립근거</a>
# <a href="/portal/main/contents.do?menuNo=200185">한국은행 역사</a>
# <a href="/portal/main/contents.do?menuNo=200182">전략 및 조직가치</a>
# <a href="/portal/main/contents.do?menuNo=200183">주요 기능 및 역할</a>
# <a href="/portal/main/contents.do?menuNo=200184">조직도</a>
# <a href="/portal/main/contents.do?menuNo=200186">CI 소개</a>
# <a href="/portal/main/contents.do?menuNo=200503">한국은행 이용안내</a>
# <a href="/portal/main/contents.do?menuNo=200505">오시는 길</a>
# <a href="/portal/main/contents.do?menuNo=200192">총재</a>
# <a href="/portal/main/contents.do?menuNo=200192">인사말</a>
# <a href="/portal/main/contents.do?menuNo=200193">프로필</a>
# <a href="/portal/main/contents.do?menuNo=200196">역대총재</a>
# <a href="/portal/main/contents.do?menuNo=200194">금융통화위원회</a>
# <a href="/portal/main/contents.do?menuNo=200194">구성 및 운영</a>
# <a href="/portal/main/contents.do?menuNo=200195">위원현황</a>
# <a href="/portal/bbs/P0000093/list.do?menuNo=200789">의결사항</a>
# <a href="/portal/bbs/B0000245/list.do?menuNo=200761">금융통화위원회 의사록</a>
# <a href="/portal/main/contents.do?menuNo=200509">경영정보</a>
a href="/portal/singl/mainEvent/listCldr.do?menuNo=200035">행사일정</a>
# <a href="/portal/singl/mainEvent/list.do?menuNo=200036">컨퍼런스/세미나</a>
# <a href="/portal/pgm/master/list.do?progrmSeCd=01&amp;menuNo=200419">행사참가신청</a>
# <a href="/portal/bbs/B0000169/list.do?menuNo=200059">미디어센터</a>
# <a href="/portal/bbs/B0000169/list.do?menuNo=200059">총재 기자간담회</a>
# <a href="/portal/bbs/B0000170/list.do?menuNo=200060">보도자료 설명회</a>
# <a href="/portal/bbs/B0000166/list.do?menuNo=200428">컨퍼런스/세미나</a>
# <a href="/portal/bbs/B0000168/list.do?menuNo=200058">홍보·기획동영상</a>
# <a href="/portal/bbs/B0000171/list.do?menuNo=200595">공모 수상작</a>
# <a href="/portal/main/contents.do?menuNo=200172">뉴스레터</a>
# <a href="/portal/main/contents.do?menuNo=200172">뉴스레터 서비스 안내</a>
# <a href="/portal/singl/newsLetter/reqVerify.do?menuNo=200174">뉴스레터 신청</a>
# <a href="/portal/singl/newsLetter/myPage.do?pSiteId=portal&amp;menuNo=200175">신청정보 변경 및 해지</a>
# <a href="/portal/bbs/B0000204/list.do?menuNo=200042">한은소식</a>
# <a href="/portal/main/main.do"><span class="hidden">홈페이지 바로가기</span></a>
# <a class="snsLinkOpener" href="javascript:void(0);"><span class="icon-snsSet"><span class="hidden">SNS 공유하기 레이어 열고 닫기</span></span></a>
# <a href="#fbBtn" id="fbBtn" target="_blank" title="새창열림"><span class="icon-snsLink1"><span class="hidden">페이스북 공유하기</span></span></a>
# <a href="#twtBtn" id="twtBtn" title="새창열림"><span class="icon-snsLink2"><span class="hidden">트위터 공유하기</span></span></a>
# <a href="#kkStoryBtn" id="kakaoStoryBtn" title="새창열림"><span class="icon-snsLink3"><span class="hidden">카카오스토리 공유하기</span></span></a>
# <a class="hidden-lg" href="#kakao-link-btn" id="kakao-link-btn" title="새창열림"><span class="icon-snsLink4"><span class="hidden">카카오톡 공유하기</span></span></a>
# <a class="hidden-lg" href="#lineBtn" id="lineBtn" title="새창열림"><span class="icon-snsLink6"><span class="hidden">라인 공유하기</span></span></a>
# <a class="forPrint" href="/static/view/forPrint.jsp?siteId=portal" onclick="window.open(this.href, 'printPage', 'width=1100,height=550,menubar=1,scrollbars=yes,toolbar=0').focus(); return false;" target="_blank" title="새창열림"><span class="icon-print"><span class="hidden">인쇄</span></span>
# </a>
# <a class="b-pop nostyle" data-size="800,500,yes" href="/static/guide/front/portal/popup/rss_popup.html" target="_blank" title="새창열림"><span class="ico_rss"><span class="hidden">한국은행 RSS</span></span></a>
# <a class="b-white bDetailOp" href="javascript:void(0);"><i aria-hidden="true" class="fa fa-chevron-down"></i> 상세검색</a>
# <a class="secretSet" href="/portal/bbs/P0000559/view.do?nttId=10079157&amp;menuNo=200690&amp;pageIndex=1">
# <span class="title">
# <span class="titlesub">2023년 7월중 거주자외화예금 동향 </span>
# </span>
# </a>
# <a href="javascript:void(0);" title="첨부파일 레이어창열기"><span class="icon icon-etc"><span class="hidden">첨부파일 있습니다</span></span></a>
# <a href="/portal/cmmn/file/fileDown.do?menuNo=200690&amp;atchFileId=FILE_000000000041148&amp;fileSn=1" title="[보도자료] 2023년 7월중 거주자외화예금 동향_FF.hwp">
# <i class="icon-down"></i> [보도자료] 2023년 7월중 거주자외화예금 동향_FF.hwp
# 														</a>
# <a class="viewerLink" href="javascript:void(0);" onclick="fnDocViewer('portal','FILE_000000000041148', '1', 'P0000559' ); return false" rel="nofollow" title="새창열림"><span class="icon-viewer"><span class="hidden">문서보기 프로그램 새창으로 열립니다.</span></span></a>
# <a href="/portal/cmmn/file/fileDown.do?menuNo=200690&amp;atchFileId=FILE_000000000041148&amp;fileSn=2" title="[보도자료] 2023년 7월중 거주자외화예금 동향_FF.pdf">
# <i class="icon-down"></i> [보도자료] 2023년 7월중 거주자외화예금 동향_FF.pdf
# 														</a>
# <a class="viewerLink" href="javascript:void(0);" onclick="fnDocViewer('portal','FILE_000000000041148', '2', 'P0000559' ); return false" rel="nofollow" title="새창열림"><span class="icon-viewer"><span class="hidden">문서보기 프로그램 새창으로 열립니다.</span></span></a>
# <a class="secretSet" href="/portal/bbs/P0000559/view.do?nttId=10079141&amp;menuNo=200690&amp;pageIndex=1">
# <span class="title">
# <span class="titlesub">[보도참고자료] 2023년 9월중 통화안정증권 발행 계획 </span>
# </span>
# </a>
# <a href="javascript:void(0);" title="첨부파일 레이어창열기"><span class="icon icon-etc"><span class="hidden">첨부파일 있습니다</span></span></a>
# <a href="/portal/cmmn/file/fileDown.do?menuNo=200690&amp;atchFileId=FILE_000000000041142&amp;fileSn=1" title="[보도참고자료] 2023년 9월중 통화안정증권 발행 계획.hwp">
# <i class="icon-down"></i> [보도참고자료] 2023년 9월중 통화안정증권 발행 계획.hwp
# 														</a>
# <a class="viewerLink" href="javascript:void(0);" onclick="fnDocViewer('portal','FILE_000000000041142', '1', 'P0000559' ); return false" rel="nofollow" title="새창열림"><span class="icon-viewer"><span class="hidden">문서보기 프로그램 새창으로 열립니다.</span></span></a>
# <a href="/portal/cmmn/file/fileDown.do?menuNo=200690&amp;atchFileId=FILE_000000000041142&amp;fileSn=2" title="[보도참고자료] 2023년 9월중 통화안정증권 발행 계획.pdf">
# <i class="icon-down"></i> [보도참고자료] 2023년 9월중 통화안정증권 발행 계획.pdf
# 														</a>
# <a class="viewerLink" href="javascript:void(0);" onclick="fnDocViewer('portal','FILE_000000000041142', '2', 'P0000559' ); return false" rel="nofollow" title="새창열림"><span class="icon-viewer"><span class="hidden">문서보기 프로그램 새창으로 열립니다.</span></span></a>
# <a class="secretSet" href="/portal/bbs/P0000559/view.do?nttId=10079134&amp;menuNo=200690&amp;pageIndex=1">
# <span class="title">
# <span class="titlesub">경제전망(2023.8월) </span>
# </span>
# </a>
# <a href="javascript:void(0);" title="첨부파일 레이어창열기"><span class="icon icon-etc"><span class="hidden">첨부파일 있습니다</span></span></a>
# <a href="/portal/cmmn/file/fileDown.do?menuNo=200690&amp;atchFileId=FILE_000000000041124&amp;fileSn=1" title="경제전망(2023.8월).hwp">
# <i class="icon-down"></i> 경제전망(2023.8월).hwp
# 														</a>
# <a class="viewerLink" href="javascript:void(0);" onclick="fnDocViewer('portal','FILE_000000000041124', '1', 'P0000559' ); return false" rel="nofollow" title="새창열림"><span class="icon-viewer"><span class="hidden">문서보기 프로그램 새창으로 열립니다.</span></span></a>
# <a href="/portal/cmmn/file/fileDown.do?menuNo=200690&amp;atchFileId=FILE_000000000041124&amp;fileSn=2" title="경제전망(2023.8월).pdf">
# <i class="icon-down"></i> 경제전망(2023.8월).pdf
# 														</a>
# <a class="viewerLink" href="javascript:void(0);" onclick="fnDocViewer('portal','FILE_000000000041124', '2', 'P0000559' ); return false" rel="nofollow" title="새창열림"><span class="icon-viewer"><span class="hidden">문서보기 프로그램 새창으로 열립니다.</span></span></a>
# <a href="/portal/cmmn/file/fileDown.do?menuNo=200690&amp;atchFileId=FILE_000000000041124&amp;fileSn=3" title="(붙임) 국내외 경제동향 및 전망.pdf">
# <i class="icon-down"></i> (붙임) 국내외 경제동향 및 전망.pdf
# 														</a>
# <a class="viewerLink" href="javascript:void(0);" onclick="fnDocViewer('portal','FILE_000000000041124', '3', 'P0000559' ); return false" rel="nofollow" title="새창열림"><span class="icon-viewer"><span class="hidden">문서보기 프로그램 새창으로 열립니다.</span></span></a>
# <a class="secretSet" href="/portal/bbs/P0000559/view.do?nttId=10079127&amp;menuNo=200690&amp;pageIndex=1">
# <span class="title">
# <span class="titlesub">통화정책방향(2023.8.24) </span>
# </span>
# </a>
# <a href="javascript:void(0);" title="첨부파일 레이어창열기"><span class="icon icon-etc"><span class="hidden">첨부파일 있습니다</span></span></a>
# <a href="/portal/cmmn/file/fileDown.do?menuNo=200690&amp;atchFileId=FILE_000000000041112&amp;fileSn=1" title="국문보도자료(2308).hwp">
# <i class="icon-down"></i> 국문보도자료(2308).hwp
# 														</a>
# <a class="viewerLink" href="javascript:void(0);" onclick="fnDocViewer('portal','FILE_000000000041112', '1', 'P0000559' ); return false" rel="nofollow" title="새창열림"><span class="icon-viewer"><span class="hidden">문서보기 프로그램 새창으로 열립니다.</span></span></a>
# <a href="/portal/cmmn/file/fileDown.do?menuNo=200690&amp;atchFileId=FILE_000000000041112&amp;fileSn=2" title="국문보도자료(2308).pdf">
# <i class="icon-down"></i> 국문보도자료(2308).pdf
# 														</a>
# <a class="viewerLink" href="javascript:void(0);" onclick="fnDocViewer('portal','FILE_000000000041112', '2', 'P0000559' ); return false" rel="nofollow" title="새창열림"><span class="icon-viewer"><span class="hidden">문서보기 프로그램 새창으로 열립니다.</span></span></a>
# <a href="/portal/cmmn/file/fileDown.do?menuNo=200690&amp;atchFileId=FILE_000000000041112&amp;fileSn=3" title="참고자료(2308).hwp">
# <i class="icon-down"></i> 참고자료(2308).hwp
# 														</a>
# <a class="viewerLink" href="javascript:void(0);" onclick="fnDocViewer('portal','FILE_000000000041112', '3', 'P0000559' ); return false" rel="nofollow" title="새창열림"><span class="icon-viewer"><span class="hidden">문서보기 프로그램 새창으로 열립니다.</span></span></a>
# <a href="/portal/cmmn/file/fileDown.do?menuNo=200690&amp;atchFileId=FILE_000000000041112&amp;fileSn=4" title="참고자료(2308).pdf">
# <i class="icon-down"></i> 참고자료(2308).pdf
# 														</a>
# <a class="viewerLink" href="javascript:void(0);" onclick="fnDocViewer('portal','FILE_000000000041112', '4', 'P0000559' ); return false" rel="nofollow" title="새창열림"><span class="icon-viewer"><span class="hidden">문서보기 프로그램 새창으로 열립니다.</span></span></a>
# <a class="secretSet" href="/portal/bbs/P0000559/view.do?nttId=10079108&amp;menuNo=200690&amp;pageIndex=1">
# <span class="title">
# <span class="titlesub">2023년 7월 생산자물가지수 </span>
# </span>
# </a>
# <a href="javascript:void(0);" title="첨부파일 레이어창열기"><span class="icon icon-etc"><span class="hidden">첨부파일 있습니다</span></span></a>
# <a href="/portal/cmmn/file/fileDown.do?menuNo=200690&amp;atchFileId=FILE_000000000041078&amp;fileSn=1" title="[보도자료] 2023년 7월 생산자물가지수.hwp">
# <i class="icon-down"></i> [보도자료] 2023년 7월 생산자물가지수.hwp
# 														</a>
# <a class="viewerLink" href="javascript:void(0);" onclick="fnDocViewer('portal','FILE_000000000041078', '1', 'P0000559' ); return false" rel="nofollow" title="새창열림"><span class="icon-viewer"><span class="hidden">문서보기 프로그램 새창으로 열립니다.</span></span></a>
# <a href="/portal/cmmn/file/fileDown.do?menuNo=200690&amp;atchFileId=FILE_000000000041078&amp;fileSn=2" title="(보도자료)_2023년_7월_생산자물가지수(통계편).xlsx">
# <i class="icon-down"></i> (보도자료)_2023년_7월_생산자물가지수(통계편).xlsx
# 														</a>
# <a class="viewerLink" href="javascript:void(0);" onclick="fnDocViewer('portal','FILE_000000000041078', '2', 'P0000559' ); return false" rel="nofollow" title="새창열림"><span class="icon-viewer"><span class="hidden">문서보기 프로그램 새창으로 열립니다.</span></span></a>
# <a href="/portal/cmmn/file/fileDown.do?menuNo=200690&amp;atchFileId=FILE_000000000041078&amp;fileSn=3" title="[보도자료] 2023년 7월 생산자물가지수.pdf">
# <i class="icon-down"></i> [보도자료] 2023년 7월 생산자물가지수.pdf
# 														</a>
# <a class="viewerLink" href="javascript:void(0);" onclick="fnDocViewer('portal','FILE_000000000041078', '3', 'P0000559' ); return false" rel="nofollow" title="새창열림"><span class="icon-viewer"><span class="hidden">문서보기 프로그램 새창으로 열립니다.</span></span></a>
# <a class="secretSet" href="/portal/bbs/P0000559/view.do?nttId=10079044&amp;menuNo=200690&amp;pageIndex=1">
# <span class="title">
# <span class="titlesub">2023년 2/4분기 국제투자대조표(잠정) </span>
# </span>
# </a>
# <a href="javascript:void(0);" title="첨부파일 레이어창열기"><span class="icon icon-etc"><span class="hidden">첨부파일 있습니다</span></span></a>
# <a href="/portal/cmmn/file/fileDown.do?menuNo=200690&amp;atchFileId=FILE_000000000040983&amp;fileSn=1" title="(보도자료) 2023년 2분기 국제투자대조표(잠정)_f.hwp">
# <i class="icon-down"></i> (보도자료) 2023년 2분기 국제투자대조표(잠정)_f.hwp
# 														</a>
# <a class="viewerLink" href="javascript:void(0);" onclick="fnDocViewer('portal','FILE_000000000040983', '1', 'P0000559' ); return false" rel="nofollow" title="새창열림"><span class="icon-viewer"><span class="hidden">문서보기 프로그램 새창으로 열립니다.</span></span></a>
# <a href="/portal/cmmn/file/fileDown.do?menuNo=200690&amp;atchFileId=FILE_000000000040983&amp;fileSn=2" title="(보도자료) 2023년 2분기 국제투자대조표(잠정)_f.pdf">
# <i class="icon-down"></i> (보도자료) 2023년 2분기 국제투자대조표(잠정)_f.pdf
# 														</a>
# <a class="viewerLink" href="javascript:void(0);" onclick="fnDocViewer('portal','FILE_000000000040983', '2', 'P0000559' ); return false" rel="nofollow" title="새창열림"><span class="icon-viewer"><span class="hidden">문서보기 프로그램 새창으로 열립니다.</span></span></a>
# <a class="secretSet" href="/portal/bbs/P0000559/view.do?nttId=10079056&amp;menuNo=200690&amp;pageIndex=1">
# <span class="title">
# <span class="titlesub">2023년 8월 기업경기실사지수(BSI) 및 경제심리지수(ESI) </span>
# </span>
# </a>
# <a href="javascript:void(0);" title="첨부파일 레이어창열기"><span class="icon icon-etc"><span class="hidden">첨부파일 있습니다</span></span></a>
# <a href="/portal/cmmn/file/fileDown.do?menuNo=200690&amp;atchFileId=FILE_000000000041010&amp;fileSn=1" title="2308_BSI_ESI.hwp">
# <i class="icon-down"></i> 2308_BSI_ESI.hwp
# 														</a>
# <a class="viewerLink" href="javascript:void(0);" onclick="fnDocViewer('portal','FILE_000000000041010', '1', 'P0000559' ); return false" rel="nofollow" title="새창열림"><span class="icon-viewer"><span class="hidden">문서보기 프로그램 새창으로 열립니다.</span></span></a>
# <a href="/portal/cmmn/file/fileDown.do?menuNo=200690&amp;atchFileId=FILE_000000000041010&amp;fileSn=2" title="2308_BSI_ESI.pdf">
# <i class="icon-down"></i> 2308_BSI_ESI.pdf
# 														</a>
# <a class="viewerLink" href="javascript:void(0);" onclick="fnDocViewer('portal','FILE_000000000041010', '2', 'P0000559' ); return false" rel="nofollow" title="새창열림"><span class="icon-viewer"><span class="hidden">문서보기 프로그램 새창으로 열립니다.</span></span></a>
# <a class="secretSet" href="/portal/bbs/P0000559/view.do?nttId=10079046&amp;menuNo=200690&amp;pageIndex=1">
# <span class="title">
# <span class="titlesub">2023년 2/4분기중 가계신용(잠정) </span>
# </span>
# </a>
# <a href="javascript:void(0);" title="첨부파일 레이어창열기"><span class="icon icon-etc"><span class="hidden">첨부파일 있습니다</span></span></a>
# <a href="/portal/cmmn/file/fileDown.do?menuNo=200690&amp;atchFileId=FILE_000000000040985&amp;fileSn=1" title="[보도자료] 2023년 2분기 가계신용(잠정)_F.hwp">
# <i class="icon-down"></i> [보도자료] 2023년 2분기 가계신용(잠정)_F.hwp
# 														</a>
# <a class="viewerLink" href="javascript:void(0);" onclick="fnDocViewer('portal','FILE_000000000040985', '1', 'P0000559' ); return false" rel="nofollow" title="새창열림"><span class="icon-viewer"><span class="hidden">문서보기 프로그램 새창으로 열립니다.</span></span></a>
# <a href="/portal/cmmn/file/fileDown.do?menuNo=200690&amp;atchFileId=FILE_000000000040985&amp;fileSn=2" title="[보도자료] 2023년 2분기 가계신용(잠정)_F.pdf">
# <i class="icon-down"></i> [보도자료] 2023년 2분기 가계신용(잠정)_F.pdf
# 														</a>
# <a class="viewerLink" href="javascript:void(0);" onclick="fnDocViewer('portal','FILE_000000000040985', '2', 'P0000559' ); return false" rel="nofollow" title="새창열림"><span class="icon-viewer"><span class="hidden">문서보기 프로그램 새창으로 열립니다.</span></span></a>
# <a class="secretSet" href="/portal/bbs/P0000559/view.do?nttId=10079031&amp;menuNo=200690&amp;pageIndex=1">
# <span class="title">
# <span class="titlesub">2023년 8월 소비자동향조사 결과 </span>
# </span>
# </a>
# <a href="javascript:void(0);" title="첨부파일 레이어창열기"><span class="icon icon-etc"><span class="hidden">첨부파일 있습니다</span></span></a>
# <a href="/portal/cmmn/file/fileDown.do?menuNo=200690&amp;atchFileId=FILE_000000000040968&amp;fileSn=1" title="(1)2308(CSI).hwp">
# <i class="icon-down"></i> (1)2308(CSI).hwp
# 														</a>
# <a class="viewerLink" href="javascript:void(0);" onclick="fnDocViewer('portal','FILE_000000000040968', '1', 'P0000559' ); return false" rel="nofollow" title="새창열림"><span class="icon-viewer"><span class="hidden">문서보기 프로그램 새창으로 열립니다.</span></span></a>
# <a href="/portal/cmmn/file/fileDown.do?menuNo=200690&amp;atchFileId=FILE_000000000040968&amp;fileSn=2" title="(1)2308(CSI).pdf">
# <i class="icon-down"></i> (1)2308(CSI).pdf
# 														</a>
# <a class="viewerLink" href="javascript:void(0);" onclick="fnDocViewer('portal','FILE_000000000040968', '2', 'P0000559' ); return false" rel="nofollow" title="새창열림"><span class="icon-viewer"><span class="hidden">문서보기 프로그램 새창으로 열립니다.</span></span></a>
# <a class="secretSet" href="/portal/bbs/P0000559/view.do?nttId=10078971&amp;menuNo=200690&amp;pageIndex=1">
# <span class="title">
# <span class="titlesub">2023년 7월 수출입물가지수 </span>
# </span>
# </a>
# <a href="javascript:void(0);" title="첨부파일 레이어창열기"><span class="icon icon-etc"><span class="hidden">첨부파일 있습니다</span></span></a>
# <a href="/portal/cmmn/file/fileDown.do?menuNo=200690&amp;atchFileId=FILE_000000000040898&amp;fileSn=1" title="1. [보도자료] 2023년 7월 수출입물가지수_f.hwp">
# <i class="icon-down"></i> 1. [보도자료] 2023년 7월 수출입물가지수_f.hwp
# 														</a>
# <a class="viewerLink" href="javascript:void(0);" onclick="fnDocViewer('portal','FILE_000000000040898', '1', 'P0000559' ); return false" rel="nofollow" title="새창열림"><span class="icon-viewer"><span class="hidden">문서보기 프로그램 새창으로 열립니다.</span></span></a>
# <a href="/portal/cmmn/file/fileDown.do?menuNo=200690&amp;atchFileId=FILE_000000000040898&amp;fileSn=2" title="2. [보도자료] 2023년 7월 수출입물가지수_f.pdf">
# <i class="icon-down"></i> 2. [보도자료] 2023년 7월 수출입물가지수_f.pdf
# 														</a>
# <a class="viewerLink" href="javascript:void(0);" onclick="fnDocViewer('portal','FILE_000000000040898', '2', 'P0000559' ); return false" rel="nofollow" title="새창열림"><span class="icon-viewer"><span class="hidden">문서보기 프로그램 새창으로 열립니다.</span></span></a>
# <a href="/portal/cmmn/file/fileDown.do?menuNo=200690&amp;atchFileId=FILE_000000000040898&amp;fileSn=3" title="3. (통계) 2023년 7월 수출입물가지수_f.xlsx">
# <i class="icon-down"></i> 3. (통계) 2023년 7월 수출입물가지수_f.xlsx
# 														</a>
# <a class="viewerLink" href="javascript:void(0);" onclick="fnDocViewer('portal','FILE_000000000040898', '3', 'P0000559' ); return false" rel="nofollow" title="새창열림"><span class="icon-viewer"><span class="hidden">문서보기 프로그램 새창으로 열립니다.</span></span></a>
# <a href="/portal/bbs/P0000559/list.do?menuNo=200690&amp;pageIndex=1" onclick="return false;" title="처음 목록"><span class="s"><span>처음 <span class="t">목록</span></span></span></a>
# <a href="/portal/bbs/P0000559/list.do?menuNo=200690&amp;pageIndex=0" onclick="return false;" title="이전 10페이지 목록"><span class="s"><span>이전 <span class="t">10페이지 목록</span></span></span></a>
# <a href="/portal/bbs/P0000559/list.do?menuNo=200690&amp;pageIndex=2"><span>2</span></a>
# <a href="/portal/bbs/P0000559/list.do?menuNo=200690&amp;pageIndex=3"><span>3</span></a>
# <a href="/portal/bbs/P0000559/list.do?menuNo=200690&amp;pageIndex=4"><span>4</span></a>
# <a href="/portal/bbs/P0000559/list.do?menuNo=200690&amp;pageIndex=5"><span>5</span></a>
# <a href="/portal/bbs/P0000559/list.do?menuNo=200690&amp;pageIndex=6"><span>6</span></a>
# <a href="/portal/bbs/P0000559/list.do?menuNo=200690&amp;pageIndex=7"><span>7</span></a>
# <a href="/portal/bbs/P0000559/list.do?menuNo=200690&amp;pageIndex=8"><span>8</span></a>
# <a href="/portal/bbs/P0000559/list.do?menuNo=200690&amp;pageIndex=9"><span>9</span></a>
# <a href="/portal/bbs/P0000559/list.do?menuNo=200690&amp;pageIndex=10"><span>10</span></a>
# <a href="/portal/bbs/P0000559/list.do?menuNo=200690&amp;pageIndex=11" title="다음 10페이지 목록"><span class="s"><span>다음 <span class="t">10페이지 목록</span></span></span></a>
# <a href="/portal/bbs/P0000559/list.do?menuNo=200690&amp;pageIndex=1244" title="마지막 목록"><span class="s"><span>끝 <span class="t">목록</span></span></span></a>
# <a class="goTop" href="javascript:void(0);"><img alt="문서 처음으로 이동" src="/static/portal/img/common/goTop.png"/></a>
# <a href="/portal/main/contents.do?menuNo=200228">저작권보호방침</a>
# <a class="priv" href="/portal/main/contents.do?menuNo=200235">개인정보처리방침</a>
# <a href="/portal/main/contents.do?menuNo=200230">이메일무단수집거부</a>
# <a href="/portal/main/contents.do?menuNo=200238">홈페이지이용안내</a>
# <a href="/portal/main/contents.do?menuNo=200240">Contact Us</a>
# <a href="/portal/main/contents.do?menuNo=200575">관련사이트</a>
# <a class="f_logo" href="/"><img alt="한국은행 하단로고" src="/static/portal/img/common/flogo.png"/></a>
# <a class="b-pop nostyle" data-size="800,500,yes" href="/static/guide/front/portal/popup/rss_popup.html" target="_blank" title="새창열림"><img alt="한국은행 RSS" src="/static/portal/img/common/ico_rss1.png"/></a>

# %%
# 필요한 라이브러리 import
import requests
from bs4 import BeautifulSoup

# 웹 페이지 요청
url = 'https://www.bok.or.kr/portal/bbs/P0000559/list.do?menuNo=200690'
response = requests.get(url, verify=True)

# HTML 파싱
soup = BeautifulSoup(response.text, 'html.parser')

# 제목 추출
titles = soup.select('a.secretSet span.titlesub')
for title in titles:
    print(title.text.strip())
# Out:
# 2023년 7월중 거주자외화예금 동향
# [보도참고자료] 2023년 9월중 통화안정증권 발행 계획
# 경제전망(2023.8월)
# 통화정책방향(2023.8.24)
# 2023년 7월 생산자물가지수
# 2023년 2/4분기 국제투자대조표(잠정)
# 2023년 8월 기업경기실사지수(BSI) 및 경제심리지수(ESI)
# 2023년 2/4분기중 가계신용(잠정)
# 2023년 8월 소비자동향조사 결과
# 2023년 7월 수출입물가지수

# %%
# 필요한 라이브러리 import
import requests
from bs4 import BeautifulSoup

# 웹 페이지 요청
url = 'https://www.bok.or.kr/portal/bbs/P0000559/list.do?menuNo=200690'
response = requests.get(url, verify=True)

# HTML 파싱
soup = BeautifulSoup(response.text, 'html.parser')

# 제목과 첨부파일 링크 추출
press_releases = []
for item in soup.select('a.secretSet'):
    title = item.find('span', {'class': 'titlesub'}).text.strip()
    file_link_tag = item.find_next_sibling('a', href=True)
    if file_link_tag:
        file_link = 'https://www.bok.or.kr' + file_link_tag['href']
    else:
        file_link = None
    press_releases.append({
        'title': title,
        'file_link': file_link
    })

# 결과 출력
for press_release in press_releases:
    print(f"Title: {press_release['title']}")
    print(f"File Link: {press_release['file_link']}")
# Out:
# Title: 2023년 7월중 거주자외화예금 동향
# File Link: None
# Title: [보도참고자료] 2023년 9월중 통화안정증권 발행 계획
# File Link: None
# Title: 경제전망(2023.8월)
# File Link: None
# Title: 통화정책방향(2023.8.24)
# File Link: None
# Title: 2023년 7월 생산자물가지수
# File Link: None
# Title: 2023년 2/4분기 국제투자대조표(잠정)
# File Link: None
# Title: 2023년 8월 기업경기실사지수(BSI) 및 경제심리지수(ESI)
# File Link: None
# Title: 2023년 2/4분기중 가계신용(잠정)
# File Link: None
# Title: 2023년 8월 소비자동향조사 결과
# File Link: None
# Title: 2023년 7월 수출입물가지수
# File Link: None

# %%
# 필요한 라이브러리 import
import requests
from bs4 import BeautifulSoup

# 웹 페이지 요청
url = 'https://www.bok.or.kr/portal/bbs/P0000559/list.do?menuNo=200690'
response = requests.get(url, verify=True)

# HTML 파싱
soup = BeautifulSoup(response.text, 'html.parser')

# 제목과 첨부파일 링크 추출
press_releases = []
for item in soup.select('a.secretSet'):
    title = item.find('span', {'class': 'titlesub'}).text.strip()
    
    # 같은 부모 요소를 찾고, 그 아래에 있는 모든 'a' 태그를 찾습니다.
    parent = item.find_parent()
    file_links = parent.find_all('a', href=True)
    
    # 첨부파일 링크를 저장할 리스트
    file_link_list = []
    
    for link in file_links:
        if "fileDown.do" in link['href']:
            file_link = 'https://www.bok.or.kr' + link['href']
            file_link_list.append(file_link)
    
    press_releases.append({
        'title': title,
        'file_links': file_link_list
    })

# 결과 출력
for press_release in press_releases:
    print(f"Title: {press_release['title']}")
    print(f"File Links: {press_release['file_links']}")
# Out:
# Title: 2023년 7월중 거주자외화예금 동향
# File Links: []
# Title: [보도참고자료] 2023년 9월중 통화안정증권 발행 계획
# File Links: []
# Title: 경제전망(2023.8월)
# File Links: []
# Title: 통화정책방향(2023.8.24)
# File Links: []
# Title: 2023년 7월 생산자물가지수
# File Links: []
# Title: 2023년 2/4분기 국제투자대조표(잠정)
# File Links: []
# Title: 2023년 8월 기업경기실사지수(BSI) 및 경제심리지수(ESI)
# File Links: []
# Title: 2023년 2/4분기중 가계신용(잠정)
# File Links: []
# Title: 2023년 8월 소비자동향조사 결과
# File Links: []
# Title: 2023년 7월 수출입물가지수
# File Links: []

# %%
# 필요한 라이브러리 import
import requests
from bs4 import BeautifulSoup

# 웹 페이지 요청
url = 'https://www.bok.or.kr/portal/bbs/P0000559/list.do?menuNo=200690'
response = requests.get(url, verify=True)

# HTML 파싱
soup = BeautifulSoup(response.text, 'html.parser')

# 제목과 첨부파일 링크 추출
press_releases = []
for item in soup.select('a.secretSet'):
    title = item.find('span', {'class': 'titlesub'}).text.strip()
    
    # 같은 부모 요소를 찾고, 그 아래에 있는 모든 'a' 태그를 찾습니다.
    parent = item.find_parent()
    sibling_links = parent.find_next_siblings('a', href=True)
    
    # 첨부파일 링크를 저장할 리스트
    file_link_list = []
    
    for link in sibling_links:
        if "fileDown.do" in link['href']:
            file_link = 'https://www.bok.or.kr' + link['href']
            file_link_list.append(file_link)
    
    press_releases.append({
        'title': title,
        'file_links': file_link_list
    })

# 결과 출력
for press_release in press_releases:
    print(f"Title: {press_release['title']}")
    print(f"File Links: {press_release['file_links']}")
# Out:
# Title: 2023년 7월중 거주자외화예금 동향
# File Links: []
# Title: [보도참고자료] 2023년 9월중 통화안정증권 발행 계획
# File Links: []
# Title: 경제전망(2023.8월)
# File Links: []
# Title: 통화정책방향(2023.8.24)
# File Links: []
# Title: 2023년 7월 생산자물가지수
# File Links: []
# Title: 2023년 2/4분기 국제투자대조표(잠정)
# File Links: []
# Title: 2023년 8월 기업경기실사지수(BSI) 및 경제심리지수(ESI)
# File Links: []
# Title: 2023년 2/4분기중 가계신용(잠정)
# File Links: []
# Title: 2023년 8월 소비자동향조사 결과
# File Links: []
# Title: 2023년 7월 수출입물가지수
# File Links: []

# %%
# !pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: selenium in c:\users\kyungheon oh\appdata\roaming\python\python39\site-packages (4.11.2)
# Requirement already satisfied: trio~=0.17 in c:\users\kyungheon oh\appdata\roaming\python\python39\site-packages (from selenium) (0.22.2)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\kyungheon oh\appdata\roaming\python\python39\site-packages (from selenium) (0.10.3)
# Requirement already satisfied: certifi>=2021.10.8 in c:\programdata\anaconda3\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\programdata\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: attrs>=20.1.0 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\kyungheon oh\appdata\roaming\python\python39\site-packages (from trio~=0.17->selenium) (1.1.3)
# Requirement already satisfied: outcome in c:\users\kyungheon oh\appdata\roaming\python\python39\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: cffi>=1.14 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: wsproto>=0.14 in c:\users\kyungheon oh\appdata\roaming\python\python39\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\programdata\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\kyungheon oh\appdata\roaming\python\python39\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
# 웹스크래핑

from bs4 import BeautifulSoup
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# 웹 드라이버 설정 (여기서는 Chrome을 사용)
chrome_options = Options()
chrome_options.binary_location = "D:\\chromedriver\\chromedriver.exe"
driver = webdriver.Chrome(options=chrome_options)

# 웹 페이지 접속
url = 'https://www.bok.or.kr/portal/bbs/P0000559/list.do?menuNo=200690'
driver.get(url)

# 페이지 로딩 대기
time.sleep(5)

# 페이지 소스 가져오기
html = driver.page_source

# BeautifulSoup 객체 생성
soup = BeautifulSoup(html, 'html.parser')


# 제목과 첨부파일 링크 추출
press_releases = []
for item in soup.select('a.secretSet'):
    title = item.find('span', {'class': 'titlesub'}).text.strip()
    
    # 같은 부모 요소를 찾고, 그 아래에 있는 모든 'a' 태그를 찾습니다.
    parent = item.find_parent().find_parent()  # 부모의 부모 요소를 찾습니다.
    file_links = parent.find_all('a', href=True)
    
    # 첨부파일 링크를 저장할 리스트
    file_link_list = []
    
    for link in file_links:
        if "fileDown.do" in link['href']:
            file_link = 'https://www.bok.or.kr' + link['href']
            file_link_list.append(file_link)
    
    press_releases.append({
        'title': title,
        'file_links': file_link_list
    })

# 결과 출력
for press_release in press_releases:
    print(f"Title: {press_release['title']}")
    print(f"File Links: {press_release['file_links']}")

# 웹 드라이버 종료
driver.quit()
# Out:
# Title: 2023년 7월중 거주자외화예금 동향
# File Links: ['https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041148&fileSn=1', 'https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041148&fileSn=2']
# Title: [보도참고자료] 2023년 9월중 통화안정증권 발행 계획
# File Links: ['https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041142&fileSn=1', 'https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041142&fileSn=2']
# Title: 경제전망(2023.8월)
# File Links: ['https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041124&fileSn=1', 'https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041124&fileSn=2', 'https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041124&fileSn=3']
# Title: 통화정책방향(2023.8.24)
# File Links: ['https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041112&fileSn=1', 'https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041112&fileSn=2', 'https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041112&fileSn=3', 'https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041112&fileSn=4']
# Title: 2023년 7월 생산자물가지수
# File Links: ['https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041078&fileSn=1', 'https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041078&fileSn=2', 'https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041078&fileSn=3']
# Title: 2023년 2/4분기 국제투자대조표(잠정)
# File Links: ['https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000040983&fileSn=1', 'https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000040983&fileSn=2']
# Title: 2023년 8월 기업경기실사지수(BSI) 및 경제심리지수(ESI)
# File Links: ['https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041010&fileSn=1', 'https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041010&fileSn=2']
# Title: 2023년 2/4분기중 가계신용(잠정)
# File Links: ['https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000040985&fileSn=1', 'https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000040985&fileSn=2']
# Title: 2023년 8월 소비자동향조사 결과
# File Links: ['https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000040968&fileSn=1', 'https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000040968&fileSn=2']
# Title: 2023년 7월 수출입물가지수
# File Links: ['https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000040898&fileSn=1', 'https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000040898&fileSn=2', 'https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000040898&fileSn=3']

# %%
from bs4 import BeautifulSoup
import json
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# 웹 드라이버 설정 (Chrome을 사용)
chrome_options = Options()
chrome_options.binary_location = "D:\\chromedriver\\chromedriver.exe"  # 실제 경로로 변경 필요
driver = webdriver.Chrome(options=chrome_options)

# 웹 페이지 접속
url = 'https://www.bok.or.kr/portal/bbs/P0000559/list.do?menuNo=200690'
driver.get(url)

# 페이지 로딩 대기
time.sleep(5)

# 페이지 소스 가져오기
html = driver.page_source

# BeautifulSoup 객체 생성
soup = BeautifulSoup(html, 'html.parser')

# 제목과 첨부파일 링크 추출
press_releases = []
for item in soup.select('a.secretSet'):
    title = item.find('span', {'class': 'titlesub'}).text.strip()
    
    # 같은 부모 요소를 찾고, 그 아래에 있는 모든 'a' 태그를 찾습니다.
    parent = item.find_parent().find_parent()  # 부모의 부모 요소를 찾습니다.
    file_links = parent.find_all('a', href=True)
    
    # 첨부파일 링크를 저장할 리스트
    file_link_list = []
    
    for link in file_links:
        if "fileDown.do" in link['href']:
            file_link = 'https://www.bok.or.kr' + link['href']
            file_link_list.append(file_link)
    
    press_releases.append({
        'title': title,
        'file_links': file_link_list
    })

# JSON 파일에 저장
with open('press_releases.json', 'w', encoding='utf-8') as f:
    json.dump(press_releases, f, ensure_ascii=False, indent=4)

# 결과 출력 (옵션)
for press_release in press_releases:
    print(f"Title: {press_release['title']}")
    print(f"File Links: {press_release['file_links']}")

# 웹 드라이버 종료
driver.quit()
# Out:
# Title: 2023년 7월중 거주자외화예금 동향
# File Links: ['https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041148&fileSn=1', 'https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041148&fileSn=2']
# Title: [보도참고자료] 2023년 9월중 통화안정증권 발행 계획
# File Links: ['https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041142&fileSn=1', 'https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041142&fileSn=2']
# Title: 경제전망(2023.8월)
# File Links: ['https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041124&fileSn=1', 'https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041124&fileSn=2', 'https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041124&fileSn=3']
# Title: 통화정책방향(2023.8.24)
# File Links: ['https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041112&fileSn=1', 'https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041112&fileSn=2', 'https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041112&fileSn=3', 'https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041112&fileSn=4']
# Title: 2023년 7월 생산자물가지수
# File Links: ['https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041078&fileSn=1', 'https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041078&fileSn=2', 'https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041078&fileSn=3']
# Title: 2023년 2/4분기 국제투자대조표(잠정)
# File Links: ['https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000040983&fileSn=1', 'https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000040983&fileSn=2']
# Title: 2023년 8월 기업경기실사지수(BSI) 및 경제심리지수(ESI)
# File Links: ['https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041010&fileSn=1', 'https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000041010&fileSn=2']
# Title: 2023년 2/4분기중 가계신용(잠정)
# File Links: ['https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000040985&fileSn=1', 'https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000040985&fileSn=2']
# Title: 2023년 8월 소비자동향조사 결과
# File Links: ['https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000040968&fileSn=1', 'https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000040968&fileSn=2']
# Title: 2023년 7월 수출입물가지수
# File Links: ['https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000040898&fileSn=1', 'https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000040898&fileSn=2', 'https://www.bok.or.kr/portal/cmmn/file/fileDown.do?menuNo=200690&atchFileId=FILE_000000000040898&fileSn=3']

# %%
from bs4 import BeautifulSoup
import json
import time
import requests
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# 텔레그램 메시지 전송 함수
def send_telegram_message(token, chat_id, message):
    url = f"https://api.telegram.org/bot{token}/sendMessage"
    payload = {
        'chat_id': chat_id,
        'text': message
    }
    response = requests.post(url, params=payload)
    return response.json()

# 웹 드라이버 설정 (Chrome을 사용)
chrome_options = Options()
chrome_options.binary_location = "D:\\chromedriver\\chromedriver.exe"  # 실제 경로로 변경 필요
driver = webdriver.Chrome(options=chrome_options)

# 웹 페이지 접속
url = 'https://www.bok.or.kr/portal/bbs/P0000559/list.do?menuNo=200690'
driver.get(url)

# 페이지 로딩 대기
time.sleep(5)

# 페이지 소스 가져오기
html = driver.page_source

# BeautifulSoup 객체 생성
soup = BeautifulSoup(html, 'html.parser')

# 제목과 첨부파일 링크 추출
new_press_releases = []
for item in soup.select('a.secretSet'):
    title = item.find('span', {'class': 'titlesub'}).text.strip()
    parent = item.find_parent().find_parent()
    file_links = parent.find_all('a', href=True)
    
    file_link_list = []
    for link in file_links:
        if "fileDown.do" in link['href']:
            file_link = 'https://www.bok.or.kr' + link['href']
            file_link_list.append(file_link)
    
    new_press_releases.append({
        'title': title,
        'file_links': file_link_list
    })

# 이전 보도자료 로드
try:
    with open('press_releases.json', 'r', encoding='utf-8') as f:
        old_press_releases = json.load(f)
except FileNotFoundError:
    old_press_releases = []

# 새로운 보도자료 확인 및 알림 전송
for new_release in new_press_releases:
    if new_release not in old_press_releases:
        message = f"새로운 보도자료: {new_release['title']}\n첨부파일 링크: {new_release['file_links']}"
        send_telegram_message("bokoh_bot", "bok_oh", message)

# JSON 파일에 새로운 보도자료 저장
with open('press_releases.json', 'w', encoding='utf-8') as f:
    json.dump(new_press_releases, f, ensure_ascii=False, indent=4)

# 웹 드라이버 종료
driver.quit()

# %%
import requests

def get_chat_id(token):
    url = f"https://api.telegram.org/bot{token}/getUpdates"
    response = requests.get(url)
    updates = response.json()
    chat_id = updates['result'][0]['message']['chat']['id']
    return chat_id

# 사용 예시
token = "6303203671:AAFnqfiO0b_TiVisnuYUBsG3-cBkajh45xQ"
chat_id = get_chat_id(token)
print(f"Your chat ID is: {chat_id}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27124\2917820144.py in <module>
#      10 # 사용 예시
#      11 token = "6303203671:AAFnqfiO0b_TiVisnuYUBsG3-cBkajh45xQ"
# ---> 12 chat_id = get_chat_id(token)
#      13 print(f"Your chat ID is: {chat_id}")
#
# ~\AppData\Local\Temp\ipykernel_27124\2917820144.py in get_chat_id(token)
#       5     response = requests.get(url)
#       6     updates = response.json()
# ----> 7     chat_id = updates['result'][0]['message']['chat']['id']
#       8     return chat_id
#       9
#
# KeyError: 'result'

# %%
import requests

def get_chat_id(token):
    url = f"https://api.telegram.org/bot{token}/getUpdates"
    response = requests.get(url)
    updates = response.json()
    print(updates)  # 응답 출력
    chat_id = updates['result'][0]['message']['chat']['id']
    return chat_id

# 사용 예시
token = "6019854993:AAHTbTZu8g2RKQQyDXZD9bzsERo27y6ya_Y"
chat_id = get_chat_id(token)
print(f"Your chat ID is: {chat_id}")
# Out:
# {'ok': True, 'result': [{'update_id': 590052837, 'message': {'message_id': 3, 'from': {'id': 6580852850, 'is_bot': False, 'first_name': 'Sy', 'last_name': 'J', 'username': 'bok_oh', 'language_code': 'ko'}, 'chat': {'id': 6580852850, 'first_name': 'Sy', 'last_name': 'J', 'username': 'bok_oh', 'type': 'private'}, 'date': 1693235552, 'text': '하'}}, {'update_id': 590052838, 'message': {'message_id': 4, 'from': {'id': 6580852850, 'is_bot': False, 'first_name': 'Sy', 'last_name': 'J', 'username': 'bok_oh', 'language_code': 'ko'}, 'chat': {'id': 6580852850, 'first_name': 'Sy', 'last_name': 'J', 'username': 'bok_oh', 'type': 'private'}, 'date': 1693235555, 'text': '이'}}, {'update_id': 590052839, 'message': {'message_id': 5, 'from': {'id': 6580852850, 'is_bot': False, 'first_name': 'Sy', 'last_name': 'J', 'username': 'bok_oh', 'language_code': 'ko'}, 'chat': {'id': 6580852850, 'first_name': 'Sy', 'last_name': 'J', 'username': 'bok_oh', 'type': 'private'}, 'date': 1693235561, 'text': '1'}}]}
# Your chat ID is: 6580852850

# %%
from bs4 import BeautifulSoup
import json
from json import JSONDecodeError
import time
import requests
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# 설정 파일 불러오기
with open('config.json', 'r') as f:
    config = json.load(f)

# 텔레그램 메시지 전송 함수
def send_telegram_message(token, chat_id, message):
    url = f"https://api.telegram.org/bot{token}/sendMessage"
    payload = {
        'chat_id': chat_id,
        'text': message
    }
    requests.post(url, params=payload)

# 웹 드라이버 설정
chrome_options = Options()
chrome_options.binary_location = config['chrome_driver_path']  # 설정 파일에서 불러오기
driver = webdriver.Chrome(options=chrome_options)

# 웹 페이지 접속
url = 'https://www.bok.or.kr/portal/bbs/P0000559/list.do?menuNo=200690'
driver.get(url)

# 페이지 로딩 대기
time.sleep(5)

# 페이지 소스 가져오기
html = driver.page_source

# BeautifulSoup 객체 생성
soup = BeautifulSoup(html, 'html.parser')

# 제목과 첨부파일 링크 추출
new_press_releases = []
for item in soup.select('a.secretSet'):
    title = item.find('span', {'class': 'titlesub'}).text.strip()
    parent = item.find_parent().find_parent()
    file_links = parent.find_all('a', href=True)
    
    file_link_list = []
    for link in file_links:
        if "fileDown.do" in link['href']:
            file_link = 'https://www.bok.or.kr' + link['href']
            file_link_list.append(file_link)
    
    new_press_releases.append({
        'title': title,
        'file_links': file_link_list
    })

# 이전에 저장된 보도자료 불러오기
try:
    with open('press_releases.json', 'r', encoding='utf-8') as f:
        old_press_releases = json.load(f)
except (FileNotFoundError, JSONDecodeError):
    old_press_releases = []    
    
# 새로운 보도자료가 있는지 확인
for new_release in new_press_releases:
    if new_release not in old_press_releases:
        message = f"새로운 보도자료: {new_release['title']}\n첨부파일 링크: {', '.join(new_release['file_links'])}"
        
        # 텔레그램 알림 전송
        send_telegram_message(config['telegram_token'], config['telegram_chat_id'], message)  # 설정 파일에서 불러오기

# 새로운 보도자료 저장
with open('press_releases.json', 'w', encoding='utf-8') as f:
    json.dump(new_press_releases, f, ensure_ascii=False, indent=4)

# 웹 드라이버 종료
driver.quit()

# %%
import json

config_data = {
    "telegram_token": "6019854993:AAHTbTZu8g2RKQQyDXZD9bzsERo27y6ya_Y",
    "telegram_chat_id": "6580852850",
    "chrome_driver_path": "D:\\chromedriver\\chromedriver.exe"
}

with open('config.json', 'w') as f:
    json.dump(config_data, f, indent=4)
